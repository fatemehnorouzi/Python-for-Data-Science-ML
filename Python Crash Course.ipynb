# %%
1/2.0
# Out:
# 0.5

# %%
3**3
# Out:
# 27

# %%
2+3+5*5
# Out:
# 30

# %%
4%2
# Out:
# 0

# %%
5%2
# Out:
# 1

# %%
x=2
y=3
x= x+y
x= x-y
x
# Out:
# 2

# %%
x= x+y
y= x-y

# %%
y
# Out:
# 2

# %%
x= x-y

# %%
x
# Out:
# 3

# %%
num=12
name= 'Fatinorouzi'

# %%
print(f"My number is {num} and My name is {name}")
# Out:
# My number is 12 and My name is Fatinorouzi

# %%
name[0]
# Out:
# 'F'

# %%
name[-1]
# Out:
# 'i'

# %%
name[0:2]
# Out:
# 'Fa'

# %%
name[2:]
# Out:
# 'tinorouzi'

# %%
name[:5]
# Out:
# 'Fatin'

# %%
name[2:6]
# Out:
# 'tino'

# %%
my_list=['a', 'b', 'c']

# %%
my_list.append('d')

# %%
my_list
# Out:
# ['a', 'b', 'c', 'd']

# %%
my_list[0:2]
# Out:
# ['a', 'b']

# %%
my_list[:-1]
# Out:
# ['new', 'w', 'c']

# %%
my_list[:2]= ['new']

# %%
my_list
# Out:
# ['new', 'c', 'd']

# %%
my_list[1]= 'old'

# %%
my_list
# Out:
# ['new', 'old', 'd']

# %%
new_list= [1, 2, 3, [4, 5, ['target']]]

# %%
new_list[-1]
# Out:
# [4, 5, ['target']]

# %%
new_list[3][-1]
# Out:
# ['target']

# %%
print(new_list[3][2][0])
# Out:
# target

# %%
dict={'k1': [1, 2, 3], 'k2': 'value2'}

# %%
dict['k1'][1]
# Out:
# 2

# %%
dict['k2']
# Out:
# 'value2'

# %%
key= {'k1':{'inner key': [1, 2, 3]}}

# %%
key['k1']
# Out:
# {'inner key': [1, 2, 3]}

# %%
key['k1']['inner key'][-1]
# Out:
# 3

# %%
t= (1, 2, 3)

# %%
t[0]
# Out:
# 1

# %%
set={1, 2, 3}

# %%
set.add(6)

# %%
set
# Out:
# {1, 2, 3, 6}

# %%
1 == -1
# Out:
# False

# %%
1 != 3
# Out:
# True

# %%
item=[1, 2, 3, 4, 5, 6]
for i in item:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
i =1
while i in range(6):
    print(f"Number {i}")
    i+=1
# Out:
# Number 1
# Number 2
# Number 3
# Number 4
# Number 5

# %%
item=[1, 2, 3, 4, 5, 6]

# %%
l=[]
for num in item:
    l.append(num**2)

print(l)
# Out:
# [1, 4, 9, 16, 25, 36]

# %%
def mult(num):
    return num*2


seq= [1, 2, 3, 4, 5]

# %%
del list

# %%
number= [1, 2, 3, 4]
list(filter(lambda num: num%2==0, number))
# Out:
# [2, 4]

# %%
s= 'Hello My Name if Fati'

# %%
s.lower()
# Out:
# 'hello my name if fati'

# %%
s.upper()
# Out:
# 'HELLO MY NAME IF FATI'

# %%
s.split()
# Out:
# ['Hello', 'My', 'Name', 'if', 'Fati']

# %%
x= [(1, 2), (3, 4), (5, 6)]

# %%
for (a, b) in x:
    print (b)
# Out:
# 2
# 4
# 6
